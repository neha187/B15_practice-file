# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('countries.csv')
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
#china and canada

# %%
china = data[data.country == 'China']
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
canada = data[data.country == 'Canada']
canada
# Out:
#     country  year  population
# 240  Canada  1952    14785584
# 241  Canada  1957    17010154
# 242  Canada  1962    18985849
# 243  Canada  1967    20819767
# 244  Canada  1972    22284500
# 245  Canada  1977    23796400
# 246  Canada  1982    25201900
# 247  Canada  1987    26549700
# 248  Canada  1992    28523502
# 249  Canada  1997    30305843
# 250  Canada  2002    31902268
# 251  Canada  2007    33390141

# %%
plt.plot(china.year,china.population)
plt.plot(canada.year,canada.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparison')
plt.legend(['Canada','china'])
plt.show()

# %%
#swaziland and sweden

# %%
swaziland = data[data.country == 'Swaziland']
swaziland
# Out:
#         country  year  population
# 1452  Swaziland  1952      290243
# 1453  Swaziland  1957      326741
# 1454  Swaziland  1962      370006
# 1455  Swaziland  1967      420690
# 1456  Swaziland  1972      480105
# 1457  Swaziland  1977      551425
# 1458  Swaziland  1982      649901
# 1459  Swaziland  1987      779348
# 1460  Swaziland  1992      962344
# 1461  Swaziland  1997     1054486
# 1462  Swaziland  2002     1130269
# 1463  Swaziland  2007     1133066

# %%
sweden = data[data.country == 'Sweden']
sweden
# Out:
#      country  year  population
# 1464  Sweden  1952     7124673
# 1465  Sweden  1957     7363802
# 1466  Sweden  1962     7561588
# 1467  Sweden  1967     7867931
# 1468  Sweden  1972     8122293
# 1469  Sweden  1977     8251648
# 1470  Sweden  1982     8325260
# 1471  Sweden  1987     8421403
# 1472  Sweden  1992     8718867
# 1473  Sweden  1997     8897619
# 1474  Sweden  2002     8954175
# 1475  Sweden  2007     9031088

# %%
plt.plot(swaziland.year,china.population)
plt.plot(sweden.year,sweden.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparison')
plt.legend(['swaziland','sweden'])
plt.show()

# %%
#norway and oman

# %%
norway = data[data.country == 'Norway']
norway
# Out:
#      country  year  population
# 1140  Norway  1952     3327728
# 1141  Norway  1957     3491938
# 1142  Norway  1962     3638919
# 1143  Norway  1967     3786019
# 1144  Norway  1972     3933004
# 1145  Norway  1977     4043205
# 1146  Norway  1982     4114787
# 1147  Norway  1987     4186147
# 1148  Norway  1992     4286357
# 1149  Norway  1997     4405672
# 1150  Norway  2002     4535591
# 1151  Norway  2007     4627926

# %%
oman = data[data.country == 'Oman']
oman
# Out:
#      country  year  population
# 1152    Oman  1952      507833
# 1153    Oman  1957      561977
# 1154    Oman  1962      628164
# 1155    Oman  1967      714775
# 1156    Oman  1972      829050
# 1157    Oman  1977     1004533
# 1158    Oman  1982     1301048
# 1159    Oman  1987     1593882
# 1160    Oman  1992     1915208
# 1161    Oman  1997     2283635
# 1162    Oman  2002     2713462
# 1163    Oman  2007     3204897

# %%
plt.plot(norway.year,norway.population)
plt.plot(oman.year,oman.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparison')
plt.legend(['norway','oman'])
plt.show()

# %%
#japan and italy

# %%
japan = data[data.country == 'Japan']
japan
# Out:
#     country  year  population
# 792   Japan  1952    86459025
# 793   Japan  1957    91563009
# 794   Japan  1962    95831757
# 795   Japan  1967   100825279
# 796   Japan  1972   107188273
# 797   Japan  1977   113872473
# 798   Japan  1982   118454974
# 799   Japan  1987   122091325
# 800   Japan  1992   124329269
# 801   Japan  1997   125956499
# 802   Japan  2002   127065841
# 803   Japan  2007   127467972

# %%
italy = data[data.country == 'Italy']
italy
# Out:
#     country  year  population
# 768   Italy  1952    47666000
# 769   Italy  1957    49182000
# 770   Italy  1962    50843200
# 771   Italy  1967    52667100
# 772   Italy  1972    54365564
# 773   Italy  1977    56059245
# 774   Italy  1982    56535636
# 775   Italy  1987    56729703
# 776   Italy  1992    56840847
# 777   Italy  1997    57479469
# 778   Italy  2002    57926999
# 779   Italy  2007    58147733

# %%
plt.plot(italy.year,italy.population)
plt.plot(japan.year,japan.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparison')
plt.legend(['italy','japan'])
plt.show()

# %%
#germany and greece

# %%
germany = data[data.country == 'Germany']
germany
# Out:
#      country  year  population
# 564  Germany  1952    69145952
# 565  Germany  1957    71019069
# 566  Germany  1962    73739117
# 567  Germany  1967    76368453
# 568  Germany  1972    78717088
# 569  Germany  1977    78160773
# 570  Germany  1982    78335266
# 571  Germany  1987    77718298
# 572  Germany  1992    80597764
# 573  Germany  1997    82011073
# 574  Germany  2002    82350671
# 575  Germany  2007    82400996

# %%
greece = data[data.country == 'Greece']
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(germany.year,germany.population)
plt.plot(greece.year,greece.population)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparison')
plt.legend(['germany','greece'])
plt.show()
