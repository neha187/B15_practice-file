# %%
#creating a data frame

# %%
import numpy as np
import pandas as pd

# %%
games = {
    'name': ['minakshi','madhuri','nisha','arsh'],
    'game': ['football','cricket','chess','carom']
}
df = pd.DataFrame(games)
df
# Out:
#        name      game
# 0  minakshi  football
# 1   madhuri   cricket
# 2     nisha     chess
# 3      arsh     carom

# %%
# understanding the data set:

# %%
df = pd.read_csv('C:\\Users\\NEHA\\Downloads\\artwork_data.csv',nrows = 4)
df
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
# 3  1038           A00004  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
#
# ...

# %%
#req: to get the columns id,artist,title
df = pd.read_csv('C:\\Users\\NEHA\\Downloads\\artwork_data.csv',nrows = 4,index_col = 'id',usecols = ['id','artist','title'])
df
# Out:
#              artist                                              title
# id
# 1035  Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036  Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037  Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038  Blake, Robert     Six Drawings of Figures with Outstretched Arms

# %%
#req: want to add more columns:
Columns = ['id','medium','year']
df = pd.read_csv('C:\\Users\\NEHA\\Downloads\\artwork_data.csv',nrows = 4,index_col = 'id',usecols = Columns)
df
# Out:
#                                                  medium    year
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN
# 1036                                  Graphite on paper     NaN
# 1037        Graphite on paper. Verso: graphite on paper  1785.0
# 1038                                  Graphite on paper     NaN

# %%
pickle seralisation

# %%
df.to_pickle('dataframe_new.pickle')

# %%
x = pd.read_pickle('dataframe_new.pickle')
x
# Out:
#                                                  medium    year
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN
# 1036                                  Graphite on paper     NaN
# 1037        Graphite on paper. Verso: graphite on paper  1785.0
# 1038                                  Graphite on paper     NaN
